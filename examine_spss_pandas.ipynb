# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#create pandas DataFrame
df = pd.DataFrame({'team': ['A', 'A', 'B', 'B', 'B', 'C', 'C'],
                   'division':['E', 'W', 'E', 'E', 'W', 'W', 'E'],
                   'rebounds': [11, 8, 7, 6, 6, 5, 12]})

# %%
#display DataFrame
print(df)
# Out:
#   team division  rebounds
# 0    A        E        11
# 1    A        W         8
# 2    B        E         7
# 3    B        E         6
# 4    B        W         6
# 5    C        W         5
# 6    C        E        12

# %%
#open dataset
df = pd.read_spss('../Practice Data/AE_Data_practice.sav')

# %%
print(df)
# Out:
#      sys_RespNum      Month QtaMonth           S1  S3   S4  S5  \
# 0            1.0       July    April  Yes, myself  No  Yes  No
# 1           14.0       July    April  Yes, myself  No  Yes  No
# 2           15.0       July    April  Yes, myself  No  Yes  No
# 3           19.0       July    April  Yes, myself  No  Yes  No
# 4           21.0       July    April  Yes, myself  No  Yes  No
# ..           ...        ...      ...          ...  ..  ...  ..
# 105       5015.0  September     June  Yes, myself  No  Yes  No
# 106       5016.0  September     June  Yes, myself  No  Yes  No
# 107       5018.0  September     June  Yes, myself  No  Yes  No
# 108       5019.0  September     June  Yes, myself  No  Yes  No
# 109       5020.0  September     June  Yes, myself  No  Yes  No
#
#                                              Q1  \
# 0                              Common knowledge
# 1                              Common knowledge
# 2    Friend, family or coworker (word of mouth)
# 3                                     All other
# 4    Friend, family or coworker (word of mouth)
# ..                                          ...
# 105  Friend, family or coworker (word of mouth)
# 106      City representative/ official/employee
# 107                            Common knowledge
# 108      City representative/ official/employee
# 109      City representative/ official/employee
#
#                                 Q1_7_other       Q2_1  ... ContactInfo_last  \
# 0     I live in Austin, so I already knew.  Unchecked  ...           Tasoya
# 1                             Already knew  Unchecked  ...          Refused
# 2                                           Unchecked  ...           Tellez
# 3        Found it in the dog pound website  Unchecked  ...             Finn
# 4                                           Unchecked  ...      Blankenship
# ..                                     ...        ...  ...              ...
# 105                                         Unchecked  ...          Refused
# 106                                         Unchecked  ...        Sefuentes
# 107                  Already knew about it  Unchecked  ...          Refused
# 108                                           Checked  ...          Refused
# 109  Call 211 and they told me to call 311  Unchecked  ...             Pega
#
#               ContactInfo_email ContactInfo_Phone  InterID  \
# 0                       Refused        5122179569  18147.0
# 1                       Refused        5122217306  18147.0
# 2      tellezmaria533@gmail.com        7373461919  17571.0
# 3        dennisfinn37@gmail.com        5122689009  18147.0
# 4    jaz@jasmineblankenship.com        5122966135  18147.0
# ..                          ...               ...      ...
# 105                     Refused        5125798212  17571.0
# 106        jesusj1630@gmail.com        7377018616  18147.0
# 107                     Refused        7372914150  17571.0
# 108                     Refused        7372672344  17571.0
# 109                     Refused        5126099482  18147.0
#
#                   sys_StartTime                 sys_EndTime    Date   Quarter  \
# 0    21 Jul 2022 - 11:44:25 CDT  21 Jul 2022 - 11:57:57 CDT  072022  FY2022Q4
# 1    21 Jul 2022 - 13:02:36 CDT  21 Jul 2022 - 13:13:34 CDT  072022  FY2022Q4
# 2    21 Jul 2022 - 13:12:54 CDT  21 Jul 2022 - 13:24:07 CDT  072022  FY2022Q4
# 3    21 Jul 2022 - 14:04:56 CDT  21 Jul 2022 - 14:18:20 CDT  072022  FY2022Q4
# 4    21 Jul 2022 - 14:38:47 CDT  21 Jul 2022 - 14:52:10 CDT  072022  FY2022Q4
# ..                          ...                         ...     ...       ...
# 105  24 Sep 2022 - 11:55:53 CDT  24 Sep 2022 - 12:06:58 CDT  092022  FY2022Q4
# 106  24 Sep 2022 - 11:56:17 CDT  24 Sep 2022 - 12:16:55 CDT  092022  FY2022Q4
# 107  24 Sep 2022 - 13:13:16 CDT  24 Sep 2022 - 13:35:51 CDT  092022  FY2022Q4
# 108  24 Sep 2022 - 13:59:47 CDT  24 Sep 2022 - 14:09:35 CDT  092022  FY2022Q4
# 109  24 Sep 2022 - 14:27:29 CDT  24 Sep 2022 - 14:42:03 CDT  092022  FY2022Q4
#
#     CustomerType RecordID
# 0    Residential   1426.0
# 1    Residential   1423.0
# 2    Residential     52.0
# 3    Residential   1394.0
# 4    Residential   1351.0
# ..           ...      ...
# 105  Residential   3304.0
# 106  Residential   4226.0
# 107  Residential   4180.0
# 108  Residential   4166.0
# 109  Residential   3351.0
#
# [110 rows x 169 columns]

# %%
print(df[['Q4#_1']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 print(df[['Q4#_1']])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6168, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6166     if use_interval_msg:
#    6167         key = list(key)
# -> 6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Q4#_1'], dtype='object')] are in the [columns]"

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 169 columns):
#  #    Column             Dtype
# ---   ------             -----
#  0    sys_RespNum        float64
#  1    Month              category
#  2    QtaMonth           category
#  3    S1                 category
#  4    S3                 category
#  5    S4                 category
#  6    S5                 category
#  7    Q1                 category
#  8    Q1_7_other         object
#  9    Q2_1               category
#  10   Q2_2               category
#  11   Q2_3               category
#  12   Q2_4               category
#  13   Q2_4_other         object
#  14   Q2A_1              category
#  15   Q2A_2              category
#  16   Q2A_3              category
#  17   Q2A_4              category
#  18   Q2A_5              category
#  19   Q2A_6              category
#  20   Q2A_7              category
#  21   Q2A_8              category
#  22   Q2A_9              category
#  23   Q2A_10             category
#  24   Q2A_11             category
#  25   Q2A_12             category
#  26   Q2A_13             category
#  27   Q2A_14             category
#  28   Q2A_15             category
#  29   Q2A_16             category
#  30   Q2A_17             category
#  31   Q2A_18             category
#  32   Q2A_19             category
#  33   Q2A_20             category
#  34   Q2A_21             category
#  35   Q2A_22             category
#  36   Q2A_23             category
#  37   Q2A_24             category
#  38   Q2A_25             category
#  39   Q2A_26             category
#  40   Q2A_27             category
#  41   Q2A_28             category
#  42   Q2A_29             category
#  43   Q2A_30             category
#  44   Q2A_30_other       object
#  45   Q3A                category
#  46   Q3B                category
#  47   Q3C                category
#  48   Q4                 category
#  49   Q4A                object
#  50   Q4a_1              category
#  51   Q4a_2              category
#  52   Q4a_3              category
#  53   Q4a_4              category
#  54   Q4a_5              category
#  55   Q5                 category
#  56   Q6                 category
#  57   Q7                 category
#  58   Q8                 category
#  59   Q9                 category
#  60   Q10                category
#  61   Q11                category
#  62   Q12                category
#  63   Q13                category
#  64   Q14                category
#  65   Q15                category
#  66   Q16                category
#  67   Q16A               object
#  68   Q16A_1             category
#  69   Q16A_2             category
#  70   Q16A_3             category
#  71   Q16A_4             category
#  72   Q16A_5             category
#  73   Q16B               object
#  74   Q16B_1             category
#  75   Q16B_2             category
#  76   Q16B_3             category
#  77   Q16B_4             category
#  78   Q16B_5             category
#  79   Q17                category
#  80   VAR00002           float64
#  81   Q18                object
#  82   Q18_1              category
#  83   Q18_2              category
#  84   Q18_3              category
#  85   Q18_4              category
#  86   Q18_5              category
#  87   Q18B               category
#  88   Q18C               float64
#  89   Q19                category
#  90   Q19A               object
#  91   Q19A_1             category
#  92   Q19A_2             category
#  93   Q19A_3             category
#  94   Q19A_4             category
#  95   Q19A_5             category
#  96   Q20                category
#  97   Q20A               object
#  98   Q20A_1             category
#  99   Q20A_2             category
#  100  Q20A_3             category
#  101  Q20A_4             category
#  102  Q20A_5             category
#  103  Q21                category
#  104  Q21A               category
#  105  Q21B               category
#  106  Q21C               object
#  107  Q21C_1             category
#  108  Q21C_2             category
#  109  Q21C_3             category
#  110  Q21C_4             category
#  111  Q21C_5             category
#  112  Q22                category
#  113  Q22A               object
#  114  Q22A_1             category
#  115  Q22A_2             category
#  116  Q22A_3             category
#  117  Q22A_4             category
#  118  Q22A_5             category
#  119  Q25                category
#  120  Q26                object
#  121  Q26_1              category
#  122  Q26_2              category
#  123  Q26_3              category
#  124  Q26_4              category
#  125  Q26_5              category
#  126  Q23                category
#  127  Q23A               category
#  128  Q23B               category
#  129  Q23C               category
#  130  Q23D               object
#  131  Q23D_1             category
#  132  Q23D_2             category
#  133  Q23D_3             category
#  134  Q23D_4             category
#  135  Q23D_5             category
#  136  Q23E               object
#  137  Q23E_1             category
#  138  Q23E_2             category
#  139  Q23E_3             category
#  140  Q23E_4             category
#  141  Q23E_5             category
#  142  Q24                category
#  143  D12                category
#  144  D1A                category
#  145  D1                 category
#  146  D15                category
#  147  D4                 category
#  148  D5                 float64
#  149  D14                category
#  150  D7                 category
#  151  D9A                category
#  152  D9B_r1_c1          object
#  153  D9B_r2_c1          object
#  154  D9                 category
#  155  D13                category
#  156  D10                category
#  157  D11                category
#  158  ContactInfo_first  object
#  159  ContactInfo_last   object
#  160  ContactInfo_email  object
#  161  ContactInfo_Phone  object
#  162  InterID            float64
#  163  sys_StartTime      object
#  164  sys_EndTime        object
#  165  Date               object
#  166  Quarter            object
#  167  CustomerType       object
#  168  RecordID           float64
# dtypes: category(138), float64(6), object(25)
# memory usage: 62.9+ KB
